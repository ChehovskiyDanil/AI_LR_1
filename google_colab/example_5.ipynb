# %%
# %timeit sum(range(1000))
# Out:
# 9.75 µs ± 61.9 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %%time
total = sum(range(10**6))
# Out:
# CPU times: user 11.9 ms, sys: 0 ns, total: 11.9 ms
# Wall time: 11.8 ms
