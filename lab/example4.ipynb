# %% [markdown]
# # Практическое задание №4

# %%
import shutil

# %%
ls
# Out:
#  ’®¬ ў гбва®©бвўҐ C ­Ґ Ё¬ҐҐв ¬ҐвЄЁ.
#  ‘ҐаЁ©­л© ­®¬Ґа в®¬ : B2DC-0F7C
#
#  ‘®¤Ґа¦Ё¬®Ґ Ї ЇЄЁ C:\Programs\Scripts\jupyter lab
#
# 19.03.2026  13:19    <DIR>          .
# 11.03.2026  19:17    <DIR>          ..
# 12.03.2026  14:41    <DIR>          .ipynb_checkpoints
# 11.03.2026  19:02               291 data.csv
# 12.03.2026  13:54             1я630 example1.ipynb
# 12.03.2026  14:06             1я851 example2.ipynb
# 12.03.2026  14:14             9я631 example3.ipynb
# 19.03.2026  13:19             2я309 example4.ipynb
# 11.03.2026  19:14            14я828 file.ipynb
# 12.03.2026  13:54             1я932 ind1.ipynb
# 11.03.2026  19:00             1я398 magic.ipynb
# 11.03.2026  18:57             1я106 markdown.ipynb
# 12.03.2026  13:46            40я292 matplotlib.ipynb
# 19.03.2026  13:17    <DIR>          new_folder
# 12.03.2026  14:17    <DIR>          test_folder
# 12.03.2026  14:13               169 test_script.py
#               11 д ©«®ў         75я437 Ў ©в
# ...

# %%
# !where python
# Out:
# C:\Users\Џ®«м§®ў вҐ«м\AppData\Local\Programs\Python\Python314\python.exe
# C:\Users\Џ®«м§®ў вҐ«м\AppData\Local\Microsoft\WindowsApps\python.exe

# %%
# !mkdir new_folder

# %%
# !rmdir new_folder

# %%
# !mkdir test_folder

# %%
clear
