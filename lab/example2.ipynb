# %% [markdown]
# # Практическое задание №2

# %%
import os

with open("Test.txt", "w") as f:
    f.write("Test\n")
    f.write("Test Test Test\n")
    f.write("Test Test Test\n")
    f.write(input("Введите свой текст:"))

with open("Test.txt", "r") as f:
    content = f.read()
    print("Содержимое файла: \n", content)

print("Файл существует:", os.path.exists("Test.txt"))

os.remove("Test.txt")
print("Файл удалён.")
# Out:
# Введите свой текст: Привет!
# Содержимое файла:
#  Test
# Test Test Test
# Test Test Test
# Привет!
# Файл существует: True
# Файл удалён.
